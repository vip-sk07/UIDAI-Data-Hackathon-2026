# %%
import pandas as pd
df = pd.read_csv("E:\\DATA ANALYTICS\\biometrics.csv")
print("Before removing duplicates:", df.shape)
df_clean = df.drop_duplicates()
print("After removing duplicates:", df_clean.shape)
df_clean.to_csv("dataset_cleaned_no_duplicates.csv", index=False)
print("Cleaned")
print(df.isnull().sum())
df.isnull().values.any()
# Out:
# Before removing duplicates: (1048575, 6)
# After removing duplicates: (1003352, 6)
# Cleaned
# date            0
# state           0
# district        0
# pincode         0
# bio_age_5_17    0
# bio_age_17_     0
# dtype: int64
# np.False_

# %%
print(df.dtypes)
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df['date']
# Out:
# date            datetime64[ns]
# state                   object
# district                object
# pincode                  int64
# bio_age_5_17             int64
# bio_age_17_              int64
# dtype: object
# 0         2025-03-01
# 1         2025-03-01
# 2         2025-03-01
# 3         2025-03-01
# 4         2025-03-01
#              ...
# 1048570   2025-11-09
# 1048571   2025-11-09
# 1048572   2025-11-09
# 1048573   2025-11-09
# 1048574   2025-11-09
# Name: date, Length: 1048575, dtype: datetime64[ns]
